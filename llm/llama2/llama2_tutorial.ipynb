# %% [markdown]
# <a href="https://colab.research.google.com/github/nukano0522/python/blob/master/llm/llama2/llama2_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install huggingface_hub transformers accelerate

# %%
#jupyter & はじめにモデルをダウンロードする場合のログイン
from huggingface_hub import notebook_login
notebook_login()


from transformers import AutoTokenizer
import transformers
import torch

#model name
# model="meta-llama/Llama-2-70b-chat-hf"
model="meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
sequences = pipeline(
    "ReactとVueの違いを、日本語で分かりやすく教えて",
    #do_sample=True,
    top_k=40,
    top_p=0.95,
    eos_token_id=tokenizer.eos_token_id,
    max_length=400,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: ReactとVueの違いを、日本語で分かりやすく教えてくれますか？
#
# Reactは、JavaScript libraries and frameworks for building user interfaces。It is designed to efficiently update and render components when the underlying data changes。React is a popular choice for building complex, data-driven applications.
#
# Vueは、MVCを基本としたJavaScript Framework for building web applications。It provides a robust ecosystem for building complex applications, including a robust component model, a powerful template language, and a robust state management system. Vue is a popular choice for building modern web applications.
#
# ReactとVueの主な違いは以下です。
#
# 1. Structure：Reactは、Component-based structureを使用し、個々のコンポーネントによって構成されます。Vueは、MVCを基本とした構造を使用し、Model、View、Controllerの3つの部分で構成されます。
# 2. Template Language：Reactは、JSXを使用し、HTMLとJavaScriptを組み合わせたtemplate languageを提供します。Vueは、Vue template languageを使用し、より強力なtemplate languageを提供します。
# 3. State Management：Reactは、FluxやReduxを使用して、状態の管理を行います。Vueは、Vuexを使用して、状態の管理を行います。
# ...
